# %% [markdown]
# <h1>Оглавление<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
import vk_api
import time
import requests

login, password = '+79165802226', 'vu1peSfoxkulak'
vk_session = vk_api.VkApi(login, password)
id = 219606837

try:
    vk_session.auth(token_only=True)
except vk_api.AuthError as error_msg:
    print(error_msg)

vk = vk_session.get_api()

response = vk.wall.get(owner_id=-33833481)
posts_num = response['count']

offset = 4400
path_to_save = "./texts/"
while posts_num > 0:
    print(offset)
    count = min(100, posts_num)
    response = vk.wall.get(owner_id=-33833481, offset=offset, count=count)
    for item in response['items']:
        for attachment in item['attachments']:
            if attachment['type'] == 'doc':
                time.sleep(1)
                response = requests.get(attachment['doc']['url'])
                print(attachment['doc']['title'])
                f = open(path_to_save + attachment['doc']['title'], "wb")
                f.write(response.content)
                f.close()
    offset += count
# Out:
# /usr/lib/python3/dist-packages/requests/__init__.py:89: RequestsDependencyWarning: urllib3 (1.26.14) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "
# 4400
# Тыбылты Алыксандр - 1988.djvu
# Туаллагов А.Д., Туаллагов А.А. - Цоцко Бицоевич..
# Российская идентичность на Северном Кавказе - 2..
# Дзалаева К.Р. - Осетинская интеллигенция - 2012..
# Хъодзаты Аехсар - Ныббар мын Дзерассае.doc
# Хаеблиаты С. - Азабаелас - 1998.djvu
# Хаеблиаты С. - Азабаелас - 1998.doc
# Хаблиев С.М. - Древо жизни - 2002.djvu
# Хаблиев С.М. - Древо жизни - 2002.doc
# Къоста (Ирон аив дзырды хаезнатае) - 1979.djvu
# Хетагуров К.Л. - Осетинская лира - 2012.djvu
# Хъуылаты Хъуыбады - Разныхас.djvu
# Хетагуров К.Л. - Особа (Этнографический очерк)..
# Хетагуров К.Л. - Особа (Этнографический очерк)..
# Мах дуг - 2010-8-9 - Музафер.doc
# Мах дуг - 2010-8-9 - Музафер.pdf
# Кокайты Т.А. Молитва души (на осет. яз.) - 2011..
# ...
